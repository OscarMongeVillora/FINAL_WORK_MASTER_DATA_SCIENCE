# %%
# %matplotlib notebook
from config_generator import config_generator
from main_project import main_project
from matplotlib import pyplot as plt

# %%
#ALL 80 ITER DEATHS WORLWIDE
# %matplotlib notebook

# %%
### CUMULATIVE DEATHS GOMPERTZ

# %%
# 1) DEFINE A CONFIGURATION TEMPLATE: DATASET WORLWIDE, CUMULATIVE MODE, GOMPERTZ, ITERATIONS_BAYES = 80
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'cum', method_trend = 'gompertz',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 49,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 80, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'gompertz', 3: 'xgb', 4: False, 6: 200, 7: 49, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# [4.21687656e+01 1.86258356e+01 6.61405690e+05]
# <img src="data:image/png;base64,..." width="899.2333333333333">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 149.0187767998831, 'max_depth': 39.68192081678027, 'learning_rate': 1.1720973834090829}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.0006934990700680815
# rmse using Bayes Optimization CV (train):  0.0009959893099777011
#
#
#  mae using Bayes Optimization CV (test):  40464.40791029408
# rmse using Bayes Optimization CV (test):  46931.917907547584

# %%
# %%capture 
#CALCULATE RMSE PREDICTIONS FOR DIFFERENT MODELS FOR DIFFERENT PROPORTIONS OF TRAIN/TEST


from datetime import datetime
start=datetime.now()

#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method22 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train22 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    for percentage_train in list_percentage_train22:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method22[method] =rmse_curve

finish = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train22, rmse_curve_method22[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:05:02.944975
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
############ CUMULATIVE DEATS NONE

# %%
# MODIFY THE CONFIGURATION TEMPLATE, DATASET WORLWIDE, CUMULATIVE MODE, NONE, ITERATIONS_BAYES = 80
#NO TREND FIT

config_template.modify_options(method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb' )

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'None', 3: 'xgb', 4: False, 6: 211, 7: 49, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="1499.9">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 108.69715141072263, 'max_depth': 11.264611195462699, 'learning_rate': 1.2798944781350954}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.004593034238750787
# rmse using Bayes Optimization CV (train):  0.007982498248568087
#
#
#  mae using Bayes Optimization CV (test):  34502.27016030106
# rmse using Bayes Optimization CV (test):  40852.23386709162

# %%
# %%capture 

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method33 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train33 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    
    for percentage_train in list_percentage_train33:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method33[method] =rmse_curve


finish = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train33, rmse_curve_method33[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:31:16.295298
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
#COMPARATION GOMPERTZ VS NULL (WON'T INCLUDE NN) CUM

fig, ax = plt.subplots(figsize=(10,6))
colour_list =['royalblue', 'darkorange', 'seagreen']
for method, colour in zip(list_methods_ml, colour_list) :
    ax.plot(list_percentage_train22, rmse_curve_method22[method], '-o', c = colour, label = method)
    ax.plot(list_percentage_train33, rmse_curve_method33[method], '--o', c= colour, label = method + ' (NO TREND FIT)')
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (GOMPERTZ FIT VS NONE)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#####

# %%
# MODIFY THE CONFIGURATION TEMPLATE, DATASET WORLWIDE, DIFFERENTIAL MODE, GOMPERTZ MODEL, ITERATIONS_BAYES = 80
#DIFFERENTIAL MODEL GOMPERT MODEL

config_template.modify_options(mode_dataset = 'diff', method_trend = 'gompertz', max_iter = 80,ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'diff', 2: 'gompertz', 3: 'xgb', 4: False, 6: 211, 7: 49, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# [4.81980254e+01 1.47372646e+01 7.44317504e+05]
# <img src="data:image/png;base64,..." width="1499.9">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 4.827121169239657, 'max_depth': 33.78215698802139, 'learning_rate': 0.47073316447006397}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  50.405927268459685
# rmse using Bayes Optimization CV (train):  87.34021270569251
#
#
#  mae using Bayes Optimization CV (test):  901.0115735808864
# rmse using Bayes Optimization CV (test):  1177.0922230060628

# %%
# %%capture 
#CALCULATE RMSE PREDICTIONS FOR DIFFERENT MODELS FOR DIFFERENT PROPORTIONS OF TRAIN/TEST


from datetime import datetime
start11=datetime.now()

#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method11 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train11 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    for percentage_train in list_percentage_train11:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method11[method] =rmse_curve

finish11 = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train11, rmse_curve_method11[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:31:16.295298
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
########

# %%
# MODIFY THE CONFIGURATION TEMPLATE, DATASET WORLWIDE, DIFFERENTIAL MODE, GOMPERTZ MODEL, ITERATIONS_BAYES = 80
#DIFFERENTIAL MODEL GOMPERT MODEL

config_template.modify_options(mode_dataset = 'diff', method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'diff', 2: 'None', 3: 'xgb', 4: False, 6: 211, 7: 49, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="1499.9">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 241.5945900001758, 'max_depth': 32.067184214422205, 'learning_rate': 1.3533692176389838}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.0006044565451319337
# rmse using Bayes Optimization CV (train):  0.0007320403418397486
#
#
#  mae using Bayes Optimization CV (test):  71.32590450784772
# rmse using Bayes Optimization CV (test):  84.59325072212687

# %%
# %%capture 
#CALCULATE RMSE PREDICTIONS FOR DIFFERENT MODELS FOR DIFFERENT PROPORTIONS OF TRAIN/TEST


from datetime import datetime
start44=datetime.now()

#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method44 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train44 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    for percentage_train in list_percentage_train44:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method44[method] =rmse_curve

finish44 = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish44-start44)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train44, rmse_curve_method44[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:32:02.487538
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
#COMPARATION GOMPERTZ VS NULL (WON'T INCLUDE NN) CUM

fig, ax = plt.subplots(figsize=(10,6))
colour_list =['royalblue', 'darkorange', 'seagreen']
for method, colour in zip(list_methods_ml, colour_list) :
    ax.plot(list_percentage_train11, rmse_curve_method11[method], '-o', c = colour, label = method)
    ax.plot(list_percentage_train44, rmse_curve_method44[method], '--o', c= colour, label = method + ' (NO TREND FIT)')
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (GOMPERTZ FIT VS NONE)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">

# %%
#FITADO POLINOMICO PARA DIFF

# %%
# MODIFY THE CONFIGURATION TEMPLATE, DATASET WORLWIDE, DIFFERENTIAL MODE, GOMPERTZ MODEL, ITERATIONS_BAYES = 80
#DIFFERENTIAL MODEL GOMPERT MODEL

config_template.modify_options(mode_dataset = 'diff', method_trend = 'sir_model', max_iter = 80,ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'diff', 2: 'sir_model', 3: 'xgb', 4: False, 6: 200, 7: 49, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 156.63693747038235, 'max_depth': 32.797307893161616, 'learning_rate': 0.01}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  252.37979697645147
# rmse using Bayes Optimization CV (train):  402.4559375828162
#
#
#  mae using Bayes Optimization CV (test):  2308.0939267485937
# rmse using Bayes Optimization CV (test):  2321.734079429455

# %%
# %%capture 
#CALCULATE RMSE PREDICTIONS FOR DIFFERENT MODELS FOR DIFFERENT PROPORTIONS OF TRAIN/TEST


from datetime import datetime
start44=datetime.now()

#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method55 = {}
data_curve_method55_07 = {}
data_curve_method55_09 = {}

for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train55 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    for percentage_train in list_percentage_train55:
        #RMSE TAKEN
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
        #PREDICTIONS TAKEN
        if percentage_train == 0.7:
            data_curve_method55_07[method] =data_out
        
        if percentage_train == 0.9:
            data_curve_method55_09[method] =data_out
            
        
    rmse_curve_method55[method] =rmse_curve

finish44 = datetime.now()

# %%
#PRINT ERRORS

fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train55, rmse_curve_method55[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#PREDICTION IN 0.9 TRAIN/TEST

data_train = data_curve_method55_09['xgb'][0]
data_test = data_curve_method55_09['xgb'][1]

fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml :
    error_test = rmse_curve_method55[method][6]
    data_train = data_curve_method55_09[method][0]
    data_test = data_curve_method55_09[method][1]
    predict_test = data_curve_method55_09[method][3]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('COVID-19 Worldwide Daily deaths')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#PREDICTION IN 0.7 TRAIN/TEST
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml :
    error_test = rmse_curve_method55[method][2]
    data_train = data_curve_method55_07[method][0]
    data_test = data_curve_method55_07[method][1]
    predict_test = data_curve_method55_07[method][3]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('COVID-19 Worldwide Daily deaths')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1104.1666666666667">

# %%
####PREDICTIONS

# %%
#PREDICCION CUMULATED NONE

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'cum', method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)

# %%
# %%capture
#BEST PREDICTIONS

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
list_methods_ml2_3 = ['xgb', 'rf', 'SARIMA']

data_curve_method2_3 = {}
rmse_curve_method2_3 = {}
for method in list_methods_ml2_3:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.7 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method2_3[method] =rmse_value
    data_curve_method2_3[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml2_3 :
    error_test = rmse_curve_method2_3[method]
    predict_test = data_curve_method2_3[method]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('COVID-19 Worldwide cumulated deaths')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#PREDICCION CUMULATED GOMPERTZ

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'cum', method_trend = 'gompertz', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)

# %%
# %%capture
#BEST PREDICTIONS

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
list_methods_ml22_33 = ['xgb', 'rf', 'SARIMA']

data_curve_method22_33 = {}
rmse_curve_method22_33 = {}
for method in list_methods_ml22_33:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.7 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method22_33[method] =rmse_value
    data_curve_method22_33[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml22_33 :
    error_test = rmse_curve_method22_33[method]
    predict_test = data_curve_method22_33[method]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('COVID-19 Worldwide cumulated deaths')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#PREDICTION DIFF NONE

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'diff', method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)

# %%
# %%capture
#BEST PREDICTIONS

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
list_methods_ml1_4 = ['xgb', 'rf', 'SARIMA']

data_curve_method1_4 = {}
rmse_curve_method1_4 = {}
for method in list_methods_ml1_4:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.9 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method1_4[method] =rmse_value
    data_curve_method1_4[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml1_4 :
    error_test = rmse_curve_method1_4[method]
    predict_test = data_curve_method1_4[method]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('COVID-19 Worldwide Daily deaths')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#REPEATING SIMULATIONS FOR SARIMA, PREDICTION

# %%
#EXPERIMENTO EXTRA 1

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'diff', method_trend = 'gompertz', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-8bb243a72d7b> in <module>
#       4
#       5 #Run the simulation  (Replace the configuration options)
# ----> 6 rmse, data = main_project(config_object = config_template)
#
# /mnt/d/MASTER_KSCHOOL/TFM/FINAL_PROJECT/main_project.py in main_project(config_object)
#     113                          bayes_tuning_on = conf[16])
#     114
# --> 115         param, eval = model.run(max_iter = conf[12])
#     116         #print(eval)
#     117         print('Optimal parameters of the ML model', param) #They aren't the last param corresponding to the last iteration. They correspond to the best rsme.
#
# /mnt/d/MASTER_KSCHOOL/TFM/FINAL_PROJECT/Bayes_Optimization/bayes_optim.py in run(self, max_iter)
#      59         if self.bayes_tuning_on == True:
#      60             self.Bayesdefinition()
# ---> 61             self.opt_search.run_optimization(max_iter)
#      62             print('The run has finished correctly')
#      63             #plot = self.opt_search.plot_convergence()
#
# ~/GPyOpt/GPyOpt/core/bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     135             # --- Update model
#     136             try:
# --> 137                 self._update_model(self.normalization_type)
#     138             except np.linalg.linalg.LinAlgError:
#     139                 break
#
# ~/GPyOpt/GPyOpt/core/bo.py in _update_model(self, normalization_type)
#     251                 Y_inmodel = self.Y
#     252
# --> 253             self.model.updateModel(X_inmodel, Y_inmodel, None, None)
#     254
#     255         # Save parameters of the model
#
# ~/GPyOpt/GPyOpt/models/gpmodel.py in updateModel(self, X_all, Y_all, X_new, Y_new)
#      91                 self.model.optimize(optimizer=self.optimizer, max_iters = self.max_iters, messages=False, ipython_notebook=False)
#      92             else:
# ---> 93                 self.model.optimize_restarts(num_restarts=self.optimize_restarts, optimizer=self.optimizer, max_iters = self.max_iters, verbose=self.verbose)
#      94
#      95     def _predict(self, X, full_cov, include_likelihood):
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/model.py in optimize_restarts(self, num_restarts, robust, verbose, parallel, num_processes, **kwargs)
#     170                     if i > 0:
#     171                         self.randomize()
# --> 172                     self.optimize(**kwargs)
#     173                 else:#pragma: no cover
#     174                     self.optimization_runs.append(jobs[i])
#
# ~/GPy/GPy/core/gp.py in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     673         self.inference_method.on_optimization_start()
#     674         try:
# --> 675             ret = super(GP, self).optimize(optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     676         except KeyboardInterrupt:
#     677             print("KeyboardInterrupt caught, calling on_optimization_end() to round things up")
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/model.py in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     109
#     110         with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook, clear_after_finish=clear_after_finish) as vo:
# --> 111             opt.run(start, f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     112
#     113         self.optimizer_array = opt.x_opt
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/optimization/optimization.py in run(self, x_init, **kwargs)
#      49     def run(self, x_init, **kwargs):
#      50         start = dt.datetime.now()
# ---> 51         self.opt(x_init, **kwargs)
#      52         end = dt.datetime.now()
#      53         self.time = str(end - start)
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/optimization/optimization.py in opt(self, x_init, f_fp, f, fp)
#     122             opt_dict['factr'] = self.bfgs_factor
#     123
# --> 124         opt_result = optimize.fmin_l_bfgs_b(f_fp, x_init, maxfun=self.max_iters, maxiter=self.max_iters, **opt_dict)
#     125         self.x_opt = opt_result[0]
#     126         self.f_opt = f_fp(self.x_opt)[0]
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/model.py in _objective_grads(self, x)
#     271     def _objective_grads(self, x):
#     272         try:
# --> 273             self.optimizer_array = x
#     274             obj_f, self.obj_grads = self.objective_function(), self._transform_gradients(self.objective_function_gradients())
#     275             self._fail_count = 0
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/parameterized.py in __setattr__(self, name, val)
#     337                 param = self.parameters[pnames.index(name)]
#     338                 param[:] = val; return
# --> 339         return object.__setattr__(self, name, val)
#     340
#     341     #===========================================================================
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/core/parameter_core.py in optimizer_array(self, p)
#     122
#     123         self._optimizer_copy_transformed = False
# --> 124         self.trigger_update()
#     125
#     126     def _trigger_params_changed(self, trigger_parent=True):
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/core/updateable.py in trigger_update(self, trigger_parent)
#      77             #print "Warning: updates are off, updating the model will do nothing"
#      78             return
# ---> 79         self._trigger_params_changed(trigger_parent)
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/core/parameter_core.py in _trigger_params_changed(self, trigger_parent)
#     132         """
#     133         [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 134         self.notify_observers(None, None if trigger_parent else -np.inf)
#     135
#     136     def _size_transformed(self):
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/core/observable.py in notify_observers(self, which, min_priority)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/core/observable.py in <listcomp>(.0)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/core/parameter_core.py in _parameters_changed_notification(self, me, which)
#     506         """
#     507         self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 508         self.parameters_changed()
#     509     def _pass_through_notify_observers(self, me, which=None):
#     510         self.notify_observers(which=which)
#
# ~/GPy/GPy/core/gp.py in parameters_changed(self)
#     274         self.posterior, self._log_marginal_likelihood, self.grad_dict = self.inference_method.inference(self.kern, self.X, self.likelihood, self.Y_normalized, self.mean_function, self.Y_metadata)
#     275         self.likelihood.update_gradients(self.grad_dict['dL_dthetaL'])
# --> 276         self.kern.update_gradients_full(self.grad_dict['dL_dK'], self.X)
#     277         if self.mean_function is not None:
#     278             self.mean_function.update_gradients(self.grad_dict['dL_dm'], self.X)
#
# ~/GPy/GPy/kern/src/kernel_slice_operations.py in wrap(self, dL_dK, X, X2, *a, **kw)
#     124     def wrap(self, dL_dK, X, X2=None, *a, **kw):
#     125         with _Slice_wrap(self, X, X2) as s:
# --> 126             ret = f(self, dL_dK, s.X, s.X2, *a, **kw)
#     127         return ret
#     128     return wrap
#
# ~/GPy/GPy/kern/src/stationary.py in update_gradients_full(self, dL_dK, X, X2, reset)
#     200
#     201         #now the lengthscale gradient(s)
# --> 202         dL_dr = self.dK_dr_via_X(X, X2) * dL_dK
#     203         if self.ARD:
#     204
#
# <decorator-gen-149> in dK_dr_via_X(self, X, X2)
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/caching.py in g(obj, *args, **kw)
#     281             else:
#     282                 cacher = cache[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs, cacher_enabled=cache.caching_enabled)
# --> 283             return cacher(*args, **kw)
#     284         g.__name__ = f.__name__
#     285         g.__doc__ = f.__doc__
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/caching.py in __call__(self, *args, **kw)
#     177             # If we need to compute, we compute the operation, but fail gracefully, if the operation has an error:
#     178             try:
# --> 179                 new_output = self.operation(*args, **kw)
#     180             except:
#     181                 self.reset()
#
# ~/GPy/GPy/kern/src/stationary.py in dK_dr_via_X(self, X, X2)
#     121         """
#     122         #a convenience function, so we can cache dK_dr
# --> 123         return self.dK_dr(self._scaled_dist(X, X2))
#     124
#     125     @Cache_this(limit=3, ignore_args=())
#
# ~/GPy/GPy/kern/src/stationary.py in dK_dr(self, r)
#     566
#     567     def dK_dr(self, r):
# --> 568         return self.variance*(10./3*r -5.*r -5.*np.sqrt(5.)/3*r**2)*np.exp(-np.sqrt(5.)*r)
#     569
#     570     def Gram_matrix(self, F, F1, F2, F3, lower, upper):
#
# ~/anaconda3/envs/masters/lib/python3.8/site-packages/paramz/core/observable_array.py in __array_wrap__(self, out_arr, context)
#      73         self._update_on = getattr(obj, '_update_on', None)
#      74
# ---> 75     def __array_wrap__(self, out_arr, context=None):
#      76         #np.ndarray.__array_wrap__(self, out_arr, context)
#      77         #return out_arr
#
# KeyboardInterrupt:

# %%
# %%capture
#BEST PREDICTIONS

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
data_curve_methodnew = {}
rmse_curve_methodnew = {}
config_template.modify_options(ML_model_choose = 'SARIMA')
size_train = round(0.9 * 222)
config_template.modify_options(size_train = size_train)

for i in range(1,15):
    rmse_value, data_out = main_project(config_object=config_template)
    data_trainnew = data_out[0]
    data_testnew = data_out[1]

    rmse_curve_methodnew[i] =rmse_value
    data_curve_methodnew[i] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_trainnew.shape[1]),data_trainnew.squeeze(), label = 'train data')
ax.plot(range(data_trainnew.shape[1], data_trainnew.shape[1] + data_testnew.shape[1]), data_testnew.squeeze(), lw=3, label = 'test data')
error_test = []
predict_test = []
for i in range(1,15) :
    if i == 6:
        i = 9
    error_test = rmse_curve_methodnew[i]
    predict_test = data_curve_methodnew[i]
    ax.plot(range(data_trainnew.shape[1], data_trainnew.shape[1] + data_testnew.shape[1]), 
            predict_test.squeeze(), lw=1)

ax.set_title('TEST PREDICTIONS FOR SARIMA (REPEATED 15 TIMES)')
ax.grid()
plt.xlabel('Days of the Time Series')
plt.ylabel('COVID-19 Worldwide Daily deaths')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(10,6))

error_test = []
predict_test = []

ax.plot(range(len(rmse_curve_methodnew.values())), [rmse for rmse in rmse_curve_methodnew.values()])

ax.set_title('ERROR TEST PREDICTIONS FOR SARIMA (REPEATED 15 TIMES)')
ax.grid()
plt.xlabel('Repetitions')
plt.ylabel('RMSE ERROR')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">
# No handles with labels found to put in legend.

# %%
#EXPERIMENTO EXTRA 2

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'diff', method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)

# %%
# %%capture
#BEST PREDICTIONS

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples

rmse_curve_methodnew = {}
#config_template.modify_options(ML_model_choose = 'SARIMA')
size_train = round(0.9 * 222)
config_template.modify_options(size_train = size_train)

for i in range(1,50, 2):
    config_template.modify_options(max_iter = i, ML_model_choose = 'SARIMA')
    rmse_value, data_out = main_project(config_object=config_template)
    rmse_curve_methodnew[i] =rmse_value
    


finish = datetime.now()

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(10,6))

error_test = []
predict_test = []

ax.plot(range(1,49, 2), [rmse for rmse in rmse_curve_methodnew.values()][:-1])

ax.set_title('ERROR TEST USING SARIMA INCREASING BAYES ITERATIONS')
ax.grid()
plt.xlabel('Repetitions')
plt.ylabel('RMSE ERROR')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">
# No handles with labels found to put in legend.

# %%
# %%capture
#BEST PREDICTIONS

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples

rmse_curve_methodnew = {}
#config_template.modify_options(ML_model_choose = 'SARIMA')
size_train = round(0.9 * 222)
config_template.modify_options(size_train = size_train)

for i in range(1,50, 2):
    config_template.modify_options(max_iter = i, ML_model_choose = 'xgb')
    rmse_value, data_out = main_project(config_object=config_template)
    rmse_curve_methodnew[i] =rmse_value
    


finish = datetime.now()

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(10,6))

error_test = []
predict_test = []

ax.plot(range(1,49, 2), [rmse for rmse in rmse_curve_methodnew.values()][:-1])

ax.set_title('ERROR TEST USING XGB INCREASING BAYES ITERATIONS')
ax.grid()
plt.xlabel('Repetitions')
plt.ylabel('RMSE ERROR')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">
# No handles with labels found to put in legend.

# %%
#PREDICTION DIFF GOMPERTZ

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'diff', method_trend = 'gompertz', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)

# %%
# %%capture
#BEST PREDICTIONS



 
from datetime import datetime
start=datetime.now()

#DATASET WORLDWIDE  222 samples

list_methods_ml11_44 = ['xgb', 'rf', 'SARIMA']

data_curve_method11_44 = {}
rmse_curve_method11_44 = {}
for method in list_methods_ml11_44:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.9 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method11_44[method] =rmse_value
    data_curve_method11_44[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml11_44 :
    error_test = rmse_curve_method11_44[method]
    predict_test = data_curve_method11_44[method]
    ax.plot(range(data_train.shape[1] +1, data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze()[1:] ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('COVID-19 Worldwide Daily deaths')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
