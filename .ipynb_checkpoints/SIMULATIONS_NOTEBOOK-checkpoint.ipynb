# %%
# %matplotlib notebook
from config_generator import config_generator
from main_project import main_project
from matplotlib import pyplot as plt

# %%
from config_generator import config_generator
from main_project import main_project
from matplotlib import pyplot as plt



# 1) DEFINE A CONFIGURATION TEMPLATE
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'diff', method_trend = 'gompertz',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 40,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 10, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
error, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'diff', 2: 'gompertz', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 10, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# [9.47858127e+01 9.34322875e+00 4.31928405e+07]
# <img src="data:image/png;base64,..." width="900">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 174.80609546349766, 'max_depth': 3.0, 'learning_rate': 0.010000000000000009}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  3782.622104095405
# rmse using Bayes Optimization CV (train):  4883.564078202998
#
#
#  mae using Bayes Optimization CV (test):  46545.279208544955
# rmse using Bayes Optimization CV (test):  55233.50006838365

# %% [markdown]
# # 1) USING DATASET WORLDWIDE

# %%
#USING GOMPERTZ TREND

# %%
# %%capture 

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA', 'NN']

rmse_curve_method = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)

        

    rmse_curve = []
    #list_percentage_train = [0.7, 0.8]
    list_percentage_train = [0.4, 0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9]
    #list_percentage_train = [0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    
    for percentage_train in list_percentage_train:
        size_train = round(percentage_train * 222)
        if method == 'NN':
            config_template.modify_options(n_sample_subset = size_train, bayes_tuning_on = False)
            
        config_template.modify_options(size_train = size_train)
        rmse_value = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method[method] =rmse_curve

# %%
#print(datetime.now()-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml[:-1]:
    ax.plot(list_percentage_train, rmse_curve_method[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'cum', method_trend = 'gompertz',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 40,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 15, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
error, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'gompertz', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 15, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# [9.46594679e+01 9.36649650e+00 4.31490665e+07]
# <img src="data:image/png;base64,..." width="900">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 270.38660394709325, 'max_depth': 4.679264534283149, 'learning_rate': 1.4362245366803583}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.003603005725794106
# rmse using Bayes Optimization CV (train):  0.004970863941520761
#
#
#  mae using Bayes Optimization CV (test):  927281.5753314241
# rmse using Bayes Optimization CV (test):  1053307.7866813361

# %%
# %matplotlib notebook

# %%
# %%capture 

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA', 'NN']

rmse_curve_method2 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)

        

    rmse_curve = []
  
    list_percentage_train2 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    
    
    for percentage_train in list_percentage_train2:
        size_train = round(percentage_train * 222)
        if method == 'NN':
            config_template.modify_options(n_sample_subset = size_train, bayes_tuning_on = False)
            
        config_template.modify_options(size_train = size_train)
        rmse_value = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method2[method] =rmse_curve


finish = datetime.now()

# %%
#print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml[:-1]:
    ax.plot(list_percentage_train2[1:], rmse_curve_method2[method][1:], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'cum', method_trend = 'None',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 40,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 15, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
error, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'None', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 15, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="900">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 164.4326473530611, 'max_depth': 3.4417755767085723, 'learning_rate': 1.5}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  86.65365386217499
# rmse using Bayes Optimization CV (train):  107.32880558879106
#
#
#  mae using Bayes Optimization CV (test):  2983167.6931696534
# rmse using Bayes Optimization CV (test):  3400622.555367638

# %%
# %%capture 

#AHORA NO HAGO NN (ANTES LO HICE Y GUARDE LA IMAGEN)
from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml3 = ['xgb', 'rf', 'SARIMA']

rmse_curve_method3 = {}
for method in list_methods_ml3:
    config_template.modify_options(ML_model_choose = method)

        

    rmse_curve = []
  
    list_percentage_train3 = [0.5, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
    
    
    for percentage_train in list_percentage_train3:
        size_train = round(percentage_train * 222)
        if method == 'NN':
            config_template.modify_options(n_sample_subset = size_train, bayes_tuning_on = False)
            
        config_template.modify_options(size_train = size_train)
        rmse_value = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method3[method] =rmse_curve


finish = datetime.now()

# %%
print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml3:
    ax.plot(list_percentage_train3[1:], rmse_curve_method3[method][1:], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:15:42.160467
# <img src="data:image/png;base64,..." width="900">

# %%
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'diff', method_trend = 'None',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 40,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 15, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
error, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'diff', 2: 'None', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 15, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="900">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 58.05890632558946, 'max_depth': 27.609035606425262, 'learning_rate': 1.1499009232372084}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.0015988720473296522
# rmse using Bayes Optimization CV (train):  0.0022140453522354574
#
#
#  mae using Bayes Optimization CV (test):  29162.4399253591
# rmse using Bayes Optimization CV (test):  31372.8331168063

# %%
# %matplotlib notebook

# %%
# %%capture 

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA', 'NN']

rmse_curve_method4 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)

        

    rmse_curve = []
  
    list_percentage_train4 = [0.5, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
    
    
    for percentage_train in list_percentage_train3:
        size_train = round(percentage_train * 222)
        if method == 'NN':
            config_template.modify_options(n_sample_subset = size_train, bayes_tuning_on = False)
            
        config_template.modify_options(size_train = size_train)
        rmse_value = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method4[method] =rmse_curve


finish = datetime.now()

# %%
#print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml[:-1]:
    ax.plot(list_percentage_train4, rmse_curve_method4[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#COMPARATION GOMPERTZ VS NULL (WON'T INCLUDE NN) CUM

fig, ax = plt.subplots(figsize=(10,6))
colour_list =['royalblue', 'darkorange', 'seagreen']
for method, colour in zip(list_methods_ml[:-1], colour_list) :
    ax.plot(list_percentage_train2[1:], rmse_curve_method2[method][1:], '-o', c = colour, label = method)
    ax.plot(list_percentage_train3[1:], rmse_curve_method3[method][1:], '--o', c= colour, label = method + ' (NO TREND FIT)')
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (GOMPERTZ FIT VS NONE)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">

# %%
#COMPARATION GOMPERTZ VS NULL (WON'T INCLUDE NN) DIFF

fig, ax = plt.subplots(figsize=(10,6))
colour_list =['royalblue', 'darkorange', 'seagreen']
for method, colour in zip(list_methods_ml[:-1], colour_list) :
    ax.plot(list_percentage_train[1:], rmse_curve_method[method][1:], '-o', c = colour, label = method)
    ax.plot(list_percentage_train[1:], rmse_curve_method4[method][1:], '--o', c= colour, label = method + ' (NO TREND FIT)')
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (GOMPERTZ FIT VS NONE)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">

# %%
# BEST PREDICTIONS:


# 1) DEFINE A CONFIGURATION TEMPLATE
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'cum', method_trend = 'gompertz',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 40,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 50, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
error_test, data_out = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'gompertz', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 50, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# [9.46594679e+01 9.36649650e+00 4.31490665e+07]
# <img src="data:image/png;base64,..." width="1500">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 267.9218619996161, 'max_depth': 38.04595290148286, 'learning_rate': 1.4567864349991095}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.003561913905174925
# rmse using Bayes Optimization CV (train):  0.004947736829913383
#
#
#  mae using Bayes Optimization CV (test):  839872.9105586968
# rmse using Bayes Optimization CV (test):  982145.752124257

# %%
# %matplotlib notebook

# %%
# %%capture 
from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml2 = ['xgb', 'rf', 'SARIMA']

data_curve_method2 = {}
rmse_curve_method2 = {}
for method in list_methods_ml2:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.9 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method2[method] =rmse_value
    data_curve_method2[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml2 :
    error_test = rmse_curve_method2[method]
    predict_test = data_curve_method2[method]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#EXTRA EXPERIMENT

# %%
# %%capture
#BEST PREDICTIONS

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples

rmse_curve_methodnew = {}
#config_template.modify_options(ML_model_choose = 'SARIMA')
size_train = round(0.9 * 222)
config_template.modify_options(size_train = size_train)

for i in range(1,50, 2):
    config_template.modify_options(max_iter = i, ML_model_choose = 'xgb')
    rmse_value, data_out = main_project(config_object=config_template)
    rmse_curve_methodnew[i] =rmse_value
    


finish = datetime.now()

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(10,6))

error_test = []
predict_test = []

ax.plot(range(1,49, 2), [rmse for rmse in rmse_curve_methodnew.values()][:-1])

ax.set_title('ERROR TEST USING XGB INCREASING BAYES ITERATIONS')
ax.grid()
plt.xlabel('Repetitions')
plt.ylabel('RMSE ERROR')
plt.legend()
plt.show()

# %%
# BEST PREDICTIONS: None


# 1) DEFINE A CONFIGURATION TEMPLATE
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'cum', method_trend = 'None',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 40,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 50, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
error_test, data_out = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'None', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 50, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="1500">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 227.59456941268718, 'max_depth': 3.1558883112531437, 'learning_rate': 1.5}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  10.596529197869767
# rmse using Bayes Optimization CV (train):  13.536846012598206
#
#
#  mae using Bayes Optimization CV (test):  2983265.6931696534
# rmse using Bayes Optimization CV (test):  3400716.929311196

# %%
# %%capture 
from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml3 = ['xgb', 'rf', 'SARIMA']

data_curve_method3 = {}
rmse_curve_method3 = {}
for method in list_methods_ml3:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.9 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method3[method] =rmse_value
    data_curve_method3[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml3 :
    error_test = rmse_curve_method3[method]
    predict_test = data_curve_method3[method]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#2A TANDA

# %%
# 1) DEFINE A CONFIGURATION TEMPLATE: DATASET WORLWIDE, CUMULATIVE MODE, GOMPERTZ, ITERATIONS_BAYES = 80
config_template = config_generator()
config_template.import_options_template(name_dataset = 'worldwide', mode_dataset = 'cum', method_trend = 'gompertz',
                                      ML_model_choose = 'xgb', predict_intervals = False, size_train = 200,
                                      list_comunities =['world'], all_comunities_bool = False, n_sample_subset = 40,
                                      loss_function = 0, timesplitmethod = 1, percentage_validation =0.3, overlap = 0.3,
                                      max_iter = 80, plot_mode = 2, metrics_print = True, plot_print = False, 
                                      bayes_tuning_on = True) 

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'gompertz', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# [9.46594679e+01 9.36649650e+00 4.31490665e+07]
# <img src="data:image/png;base64,..." width="1499.9">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 291.29549015260864, 'max_depth': 38.011264897627875, 'learning_rate': 1.4132993669017224}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.0035172027544167726
# rmse using Bayes Optimization CV (train):  0.004941873088866937
#
#
#  mae using Bayes Optimization CV (test):  845644.0724905151
# rmse using Bayes Optimization CV (test):  986420.9327477989

# %%
# %matplotlib notebook

# %%
# %%capture 
#CALCULATE RMSE PREDICTIONS FOR DIFFERENT MODELS FOR DIFFERENT PROPORTIONS OF TRAIN/TEST


from datetime import datetime
start=datetime.now()

#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method22 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train22 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    for percentage_train in list_percentage_train22:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method22[method] =rmse_curve

finish = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train22, rmse_curve_method22[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:30:33.073084
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
# MODIFY THE CONFIGURATION TEMPLATE, DATASET WORLWIDE, CUMULATIVE MODE, NONE, ITERATIONS_BAYES = 80
#NO TREND FIT

config_template.modify_options(method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb' )

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'cum', 2: 'None', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="1500">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 118.49300435742015, 'max_depth': 3.0, 'learning_rate': 1.5}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  438.4162054519555
# rmse using Bayes Optimization CV (train):  579.5508879020745
#
#
#  mae using Bayes Optimization CV (test):  2983445.238624199
# rmse using Bayes Optimization CV (test):  3400855.2515264433

# %%
# %matplotlib notebook

# %%
# %%capture 

from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method33 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train33 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    
    for percentage_train in list_percentage_train33:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method33[method] =rmse_curve


finish = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train33, rmse_curve_method33[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:30:33.073084
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
#COMPARATION GOMPERTZ VS NULL (WON'T INCLUDE NN) CUM

fig, ax = plt.subplots(figsize=(10,6))
colour_list =['royalblue', 'darkorange', 'seagreen']
for method, colour in zip(list_methods_ml, colour_list) :
    ax.plot(list_percentage_train22, rmse_curve_method22[method], '-o', c = colour, label = method)
    ax.plot(list_percentage_train33, rmse_curve_method33[method], '--o', c= colour, label = method + ' (NO TREND FIT)')
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (GOMPERTZ FIT VS NONE)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">

# %%
# MODIFY THE CONFIGURATION TEMPLATE, DATASET WORLWIDE, DIFFERENTIAL MODE, GOMPERTZ MODEL, ITERATIONS_BAYES = 80
#DIFFERENTIAL MODEL GOMPERT MODEL

config_template.modify_options(mode_dataset = 'diff', method_trend = 'gompertz', max_iter = 80)

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'diff', 2: 'gompertz', 3: 'xgb', 4: False, 6: 200, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# [9.47858127e+01 9.34322875e+00 4.31928405e+07]
# <img src="data:image/png;base64,..." width="1499.9">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 183.5548071692928, 'max_depth': 37.044770420187774, 'learning_rate': 1.4325949404649576}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.0005572945945515359
# rmse using Bayes Optimization CV (train):  0.0007341447913066311
#
#
#  mae using Bayes Optimization CV (test):  31702.44735485177
# rmse using Bayes Optimization CV (test):  43474.31800174885

# %%
# %%capture 
#CALCULATE RMSE PREDICTIONS FOR DIFFERENT MODELS FOR DIFFERENT PROPORTIONS OF TRAIN/TEST


from datetime import datetime
start11=datetime.now()

#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method11 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train11 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    for percentage_train in list_percentage_train11:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method11[method] =rmse_curve

finish11 = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish-start)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train11, rmse_curve_method11[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:30:33.073084
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
# MODIFY THE CONFIGURATION TEMPLATE, DATASET WORLWIDE, DIFFERENTIAL MODE, GOMPERTZ MODEL, ITERATIONS_BAYES = 80
#DIFFERENTIAL MODEL GOMPERT MODEL

config_template.modify_options(mode_dataset = 'diff', method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)
# Out:
# {0: 'worldwide', 1: 'diff', 2: 'None', 3: 'xgb', 4: False, 6: 211, 7: 40, 8: 0, 9: 1, 10: 0.3, 11: 0.3, 12: 80, 13: 2, 14: True, 15: False, 16: True}
# Adjusted parameters for fitting the trend:  {'world': 7}
# Total sample size of the dataset prepared:  222
# <img src="data:image/png;base64,..." width="1499.9">
# The run has finished correctly
# Optimal parameters of the ML model {'n_estimators': 229.6315678132143, 'max_depth': 17.448089212023035, 'learning_rate': 1.4490150340336256}
# The training fit is done
#
#
#  mae using Bayes Optimization CV (train):  0.0015564629311329923
# rmse using Bayes Optimization CV (train):  0.002264716736690814
#
#
#  mae using Bayes Optimization CV (test):  3756.907758791809
# rmse using Bayes Optimization CV (test):  4349.398508256134

# %%
# %%capture 
#CALCULATE RMSE PREDICTIONS FOR DIFFERENT MODELS FOR DIFFERENT PROPORTIONS OF TRAIN/TEST


from datetime import datetime
start44=datetime.now()

#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml = ['xgb', 'rf', 'SARIMA']

rmse_curve_method44 = {}
for method in list_methods_ml:
    config_template.modify_options(ML_model_choose = method)
    rmse_curve = []
    list_percentage_train44 = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
    if method == 'SARIMA':
        config_template.modify_options(max_iter = 50)
    
    for percentage_train in list_percentage_train44:
        size_train = round(percentage_train * 222)            
        config_template.modify_options(size_train = size_train)
        rmse_value, data_out = main_project(config_object=config_template)
        rmse_curve.append(rmse_value)
        
    rmse_curve_method44[method] =rmse_curve

finish44 = datetime.now()

# %%
#PLOT THE RSME CURVE FOR DIFFERENT MODELS (DIFFERENT PROPORTIONS TRAIN/TEST)

print(finish44-start44)
fig, ax = plt.subplots(figsize=(9,5))
for method in list_methods_ml:
    ax.plot(list_percentage_train44, rmse_curve_method44[method], '-o', label = method)
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (FOR DIFFERENT ML METHODS)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# 0:32:58.270560
# <img src="data:image/png;base64,..." width="899.2333333333333">

# %%
#COMPARATION GOMPERTZ VS NULL (WON'T INCLUDE NN) CUM

fig, ax = plt.subplots(figsize=(10,6))
colour_list =['royalblue', 'darkorange', 'seagreen']
for method, colour in zip(list_methods_ml, colour_list) :
    ax.plot(list_percentage_train11, rmse_curve_method11[method], '-o', c = colour, label = method)
    ax.plot(list_percentage_train44, rmse_curve_method44[method], '--o', c= colour, label = method + ' (NO TREND FIT)')
ax.set_title('RSMSE vs TRAIN/TEST PERCENTAGE (GOMPERTZ FIT VS NONE)')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'diff', method_trend = 'None', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)

# %%
# %%capture
#BEST PREDICTIONS



 
from datetime import datetime
start=datetime.now()


#DATASET WORLDWIDE  222 samples
#list_methods_ml = ['xgb', 'SARIMA', 'rf']
list_methods_ml1_4 = ['xgb', 'rf', 'SARIMA']

data_curve_method1_4 = {}
rmse_curve_method1_4 = {}
for method in list_methods_ml1_4:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.9 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method1_4[method] =rmse_value
    data_curve_method1_4[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml1_4 :
    error_test = rmse_curve_method1_4[method]
    predict_test = data_curve_method1_4[method]
    ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze() ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %%capture
# RETURN THE PREVIOUS STATE

config_template.modify_options(mode_dataset = 'diff', method_trend = 'gompertz', max_iter = 80, ML_model_choose = 'xgb')

#Run the simulation  (Replace the configuration options)
rmse, data = main_project(config_object = config_template)

# %%
# %%capture
#BEST PREDICTIONS



 
from datetime import datetime
start=datetime.now()

#DATASET WORLDWIDE  222 samples

list_methods_ml11_44 = ['xgb', 'rf', 'SARIMA']

data_curve_method11_44 = {}
rmse_curve_method11_44 = {}
for method in list_methods_ml11_44:
    config_template.modify_options(ML_model_choose = method)
    data_curve = [] 
    size_train = round(0.9 * 222)


    config_template.modify_options(size_train = size_train)
    rmse_value, data_out = main_project(config_object=config_template)
    data_train = data_out[0]
    data_test = data_out[1]

    rmse_curve_method11_44[method] =rmse_value
    data_curve_method11_44[method] =data_out[3]


finish = datetime.now()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(data_train.shape[1]),data_train.squeeze(), label = 'train data')
ax.plot(range(data_train.shape[1], data_train.shape[1] + data_test.shape[1]), data_test.squeeze(), label = 'test data')

for method in list_methods_ml11_44 :
    error_test = rmse_curve_method11_44[method]
    predict_test = data_curve_method11_44[method]
    ax.plot(range(data_train.shape[1] +1, data_train.shape[1] + data_test.shape[1]), 
            predict_test.squeeze()[1:] ,label = method +' prediction (RMSE = ' +  str(error_test)[:-8] +')')

ax.set_title('TEST PREDICTIONS FOR DIFFERENT ML MODELS')
ax.grid()
plt.xlabel('Train Percentage of Dataset')
plt.ylabel('RMSE ERROR in predictions')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
